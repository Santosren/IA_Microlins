# %% [markdown]
# Nome: Guilherme Augusto Ferreira da Silva

# %% [markdown]
# ### Importando os modulos, Pre-Processamento e Normalização

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Carregando DataSet

# %%
from sklearn.datasets import load_wine
data = load_wine()

# %%
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
list(data.target_names)
# Out:
# ['class_0', 'class_1', 'class_2']

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
pdata = pd.DataFrame(data= np.c_[data['data'], data['target']],columns= data['feature_names'] + ['target'])

# %%
type(pdata)
# Out:
# pandas.core.frame.DataFrame

# %%
print(pdata.shape)
pdata.head()
# Out:
# (178, 14)
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0     0.0
# 1                          3.40   1050.0     0.0
# 2                          3.17   1185.0     0.0
# 3                          3.45   1480.0     0.0
# 4                          2.93    735.0     0.0

# %%
#Verificando valores nulos no dataset
pdata.isnull().any()
# Out:
# alcohol                         False
# malic_acid                      False
# ash                             False
# alcalinity_of_ash               False
# magnesium                       False
# total_phenols                   False
# flavanoids                      False
# nonflavanoid_phenols            False
# proanthocyanins                 False
# color_intensity                 False
# hue                             False
# od280/od315_of_diluted_wines    False
# proline                         False
# target                          False
# dtype: bool

# %%
#Avaliando outliers atraves do describe
pdata.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#            target
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
#Avaliando outliers atraves do pair plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(pdata)
plt.show()

# %%
sns.boxplot(pdata['magnesium'])
# Out:
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Baseado na imagem acima podemos perceber alguns outliers na coluna magnesium.
# Como cheguei até essa coluna: Bati o olho nos valores de media e na distribuição dos quartetos e vi que o numero 162000
# e vi que o número estava muito acima dos demais, portanto resolvi fazer um boxplot para confirmar a suspeita de outliers

# %%
#Excluindo os outliers
from scipy import stats
zscore = np.abs(stats.zscore(pdata)) 
pdata = pdata[(zscore <3).all(axis = 1)] 
pdata.shape
# Out:
# (168, 14)

# %% [markdown]
# Obs: Testei sem retirar os outliers e o modelo ficava enviesado a 100% de acurácia rapidamente. Segue evidência no treinamento para o dataset sem esse tratamento:
# ![image.png](attachment:image.png)
#
# Na versão enviada será retirado os outliers da coluna magnesium. O melhor a se fazer seria fazer essa análise e ter essa abordagem para todas as colunas, porém por falta de tempo habil não irei executar esse procedimento por completo

# %%
#Avaliando outliers novamente
pdata.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  168.000000  168.000000  168.000000         168.000000  168.000000
# mean    13.033214    2.343571    2.369226          19.361310   98.779762
# std      0.793084    1.097823    0.243202           3.118708   12.560477
# min     11.410000    0.740000    1.700000          11.200000   70.000000
# 25%     12.370000    1.610000    2.230000          17.175000   88.000000
# 50%     13.060000    1.870000    2.360000          19.250000   97.500000
# 75%     13.695000    3.105000    2.542500          21.500000  106.250000
# max     14.830000    5.650000    2.920000          28.500000  136.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     168.000000  168.000000            168.000000       168.000000
# mean        2.273988    2.010298              0.362679         1.553155
# std         0.627890    0.985189              0.123940         0.529569
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.700000    1.097500              0.270000         1.235000
# 50%         2.265000    2.100000              0.340000         1.505000
# 75%         2.800000    2.885000              0.430000         1.870000
# max         3.880000    3.930000              0.660000         2.960000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       168.000000  168.000000                    168.000000   168.000000
# mean          5.116726    0.951226                      2.596607   752.875000
# std           2.243267    0.220522                      0.714607   319.272211
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.292500    0.787500                      1.905000   501.500000
# 50%           4.850000    0.960000                      2.775000   675.000000
# 75%           6.262500    1.112500                      3.170000  1016.250000
# max          11.750000    1.450000                      4.000000  1680.000000
#
#            target
# count  168.000000
# mean     0.934524
# std      0.790209
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Podemos observar cima que tinhamos 10 linhas consideradas outliers
# onde as mesmas impactariam negativamento o treinamento do modelo

# %%
# Podemos também ver a correlação para avaliar a exclsão de alguma coluna eventualmente
plt.subplots(figsize=(15, 10)) 
sns.heatmap(pdata.corr(),annot=True,cmap='coolwarm')

# %%
#Dividindo o dataset em treino e teste. 80% para treino e 20% para teste
from sklearn.preprocessing import MinMaxScaler
normalizando = MinMaxScaler()
dataNorm = normalizando.fit_transform(pdata.iloc[:,:-1])

X_train, X_test, y_train, y_test = train_test_split(dataNorm, pdata.target, test_size=0.2, random_state=13)
print('Treino:', X_train.shape, y_train.shape)
print('Teste:', X_test.shape, y_test.shape)
# Out:
# Treino: (134, 13) (134,)
# Teste: (34, 13) (34,)

# %% [markdown]
# ### Finalizado a parte de Carregamento preprocessamento e normalização

# %% [markdown]
# ### Treinamentos KNN:

# %%
from sklearn.metrics import accuracy_score
def treinamentoKNN(nneighbors):
    neigh = KNeighborsClassifier(n_neighbors=nneighbors)
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)
    print('n_neighbors = ' + str(nneighbors) + ' - accuracy',accuracy_score(y_test, y_pred))

# %%
for i in range(30):
    treinamentoKNN(i+5)
# Out:
# n_neighbors = 5 - accuracy 0.9411764705882353
# n_neighbors = 6 - accuracy 0.9705882352941176
# n_neighbors = 7 - accuracy 0.9411764705882353
# n_neighbors = 8 - accuracy 0.9411764705882353
# n_neighbors = 9 - accuracy 0.9411764705882353
# n_neighbors = 10 - accuracy 0.9705882352941176
# n_neighbors = 11 - accuracy 0.9411764705882353
# n_neighbors = 12 - accuracy 0.9705882352941176
# n_neighbors = 13 - accuracy 0.9705882352941176
# n_neighbors = 14 - accuracy 0.9705882352941176
# n_neighbors = 15 - accuracy 0.9705882352941176
# n_neighbors = 16 - accuracy 0.9705882352941176
# n_neighbors = 17 - accuracy 0.9705882352941176
# n_neighbors = 18 - accuracy 0.9705882352941176
# n_neighbors = 19 - accuracy 0.9411764705882353
# n_neighbors = 20 - accuracy 0.9705882352941176
# n_neighbors = 21 - accuracy 0.9705882352941176
# n_neighbors = 22 - accuracy 0.9705882352941176
# n_neighbors = 23 - accuracy 0.9705882352941176
# n_neighbors = 24 - accuracy 0.9705882352941176
# n_neighbors = 25 - accuracy 0.9411764705882353
# n_neighbors = 26 - accuracy 0.9411764705882353
# n_neighbors = 27 - accuracy 0.9411764705882353
# n_neighbors = 28 - accuracy 0.9411764705882353
# n_neighbors = 29 - accuracy 0.9411764705882353
# n_neighbors = 30 - accuracy 0.9411764705882353
# n_neighbors = 31 - accuracy 0.9411764705882353
# n_neighbors = 32 - accuracy 0.9411764705882353
# n_neighbors = 33 - accuracy 0.9411764705882353
# n_neighbors = 34 - accuracy 0.9411764705882353

# %% [markdown]
# ### Treinamentos MLP:

# %%
from sklearn.neural_network import MLPClassifier
def treinamentoMLP(ativacao,lrate,epochs):
    mlp = MLPClassifier(hidden_layer_sizes=(1000,2), alpha=1e-5,
                    solver='adam', verbose=0, random_state=1,
                    learning_rate_init=lrate, activation=ativacao,max_iter=epochs)
    mlp.fit(X_train, y_train)
    #print("Training set score: %f" % mlp.score(X_train, y_train))
    print("Test set score: %f" % mlp.score(X_test, y_test))

# %%
for i in range(30):
    if (i%2)==0:
        print("Resultado com ativação relu, lrate .1 e numero de iteração " + str(i+5))
        treinamentoMLP('relu',.1,i+5)
    else:
        print("Resultado com ativação identity, lrate .01 e numero de  iteração " + str(i+5))
        treinamentoMLP('identity',.01,i+5)
# Out:
# Resultado com ativação relu, lrate .1 e numero de iteração 5
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 6
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 7
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 8
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 9
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 10
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (6) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (7) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (8) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (9) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.970588
# Resultado com ativação relu, lrate .1 e numero de iteração 11
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 12
# Test set score: 1.000000
# Resultado com ativação relu, lrate .1 e numero de iteração 13
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 14
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (11) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (12) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (13) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (14) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 1.000000
# Resultado com ativação relu, lrate .1 e numero de iteração 15
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 16
# Test set score: 1.000000
# Resultado com ativação relu, lrate .1 e numero de iteração 17
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (16) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (17) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (18) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.441176
# Resultado com ativação identity, lrate .01 e numero de  iteração 18
# Test set score: 0.970588
# Resultado com ativação relu, lrate .1 e numero de iteração 19
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 20
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (19) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (21) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 21
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 22
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 23
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (22) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 24
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 25
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (24) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (26) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 26
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 27
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 28
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 29
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 30
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (28) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (30) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 31
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 32
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (32) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Test set score: 0.941176
# Resultado com ativação relu, lrate .1 e numero de iteração 33
# Test set score: 0.323529
# Resultado com ativação identity, lrate .01 e numero de  iteração 34
# Test set score: 0.941176
# C:\Users\gfsilva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (34) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
